# %% [markdown]
# # Statystyka matematyczna - ćwiczenia laboratoryjne 2023/2024
#
# Ten notatnik zalicza się do grupy zestawów zadań, na podstawie których odbywa się zaliczenie ćwiczeń i podlega zwrotowi do oceny w ustalonym na zajęciach terminie.
#
# Uwagi i wytyczne ogólne dotyczące uzupełniania notatnika:
# - Podczas wykonywania zadań należy korzystać wyłącznie z pakietów zaimportowanych na początku notatnika oraz z pakietów wchodzących w skład standardowej biblioteki Pythona, które można zaimportować samodzielnie we wskazanej komórce notatnika.
# - Swoje rozwiązania należy wprowadzać wyłącznie w miejce następujących fragmentów kodu:<br/> `# YOUR CODE HERE`<br/> `raise NotImplementedError()`<br/>
# a odpowiedzi tekstowe w komórkach oznaczonych hasłem:<br/>
# `YOUR ANSWER HERE`<br/>
# Nie należy w żaden sposób modyfikować pozostałych fragmentów kodu oraz innych elementów notatnika, w szczególności dodawać lub usuwać komórek oraz zmieniać nazwy pliku.
# - Otrzymywane wyniki i odpowiedzi mają być rezultatem wykonania napisanego kodu.
# - Zadanie należy wykonać w taki sposób, aby podczas wykonywania kodu nie zostały wyświetlone żadne ostrzeżenia.
# - Zawarte w notatniku automatyczne testy mają charakter poglądowy. Dotyczą one wybranych aspektów zadań i mają za zadanie wyłapać podstawowe błędy. Przejście wszystkich testów nie oznacza, że zadanie jest wykonane w całości poprawnie.
#
# Uwagi i wytyczne ogólne dotyczące wizualizacji wyników:
# - Wszystkie wykresy powinny być wykonane w jednolitym, przejrzystym i czytelnym stylu, posiadać odpowiednio dobrane proporcje i zakresy wartości osi.
# - Wykresy oraz ich osie powinny mieć nadane tytuły. Jeżeli w obrębie figury znajduje się więcej niż jeden wykres to figura również powinna mieć nadany tytuł.
# - Figury powinny mieć ustawione białe tło, tak, aby niezależnie od ustawień notatnika wszystkie elementy wykresów były dobrze widoczne (domyślnie tło jest przeźroczyste co może powodować problemy w notatnikach z ustawionym ciemnym tłem).
# - Rozmiar poziomy figur nie powinien przekraczać 20 cali.
#
# Przed odesłaniem zestawu zadań do oceny proszę uzupełnić komórkę z danymi autorów rozwiązania (nazwa zespołu oraz imiona, nazwiska i numery indeksów członków zespołu) oraz upewnić się, że notatnik działa zgodnie z oczekiwaniami. W tym celu należy skorzystać z opcji **Restart Kernel and Run All Cells...** dostępnej na górnej belce notatnika pod symbolem $\blacktriangleright\blacktriangleright$.

# %% [markdown]
# Nazwa zespołu:2.39
# Członkowie:Maria Kiraga, Bartosz Krzysik, Anna Suska,Karolina Zając

# %% [markdown]
# ---

# %% [markdown]
# # Zestaw zadań 5: Próba losowa

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Miejsce do importu pakietów wchodzących w skład standardowej biblioteki Pythona oraz ustawienie opcji wykorzystywanych pakietów

# %% [markdown]
# ### Dane do zadań
#
# W trakcie wydarzenia sportowego kibice zasiadają na stadionie w 5 różnej wielkości sektorach (1, 2 ...). Po zakończeniu wydarzenia opuszczają oni sektory przez należące do nich wyjścia (1A, 2B, ...) i przemieszczają się w kierunku bramy głównej. Po przejściu przez bramę kibice wsiadają do jednego z 16 autobusów (A01, A02 ...).
#
# ![image.png](attachment:2eac5d7d-6d0a-48d6-8dfc-dde8a233fcb9.png)
#
# Plik population.csv zawiera informacje o komplecie widzów uczestniczących w imprezie:
#  - sektor, w którym zasiadają,
#  - wyjście przez które opuszczają stadion,
#  - czas jaki zajmuje im dojście do bramy głównej kompleksu,
#  - autobus, do którego wsiadają,
#  - informacją jakiej odpowiedzi udzielą oni na pytanie o ocenę wydarzenia w skali od 0 do 100.
#
# Poniżej przedstawiono wybrane aspekty tej struktury danych:
#
# ![image.png](attachment:76bbe492-8844-4589-b382-27cc396e7ac7.png)
#
# W celu wczytania danych do notatnika umieść plik w tym samym folderze, w którym znajduje się notatnik.

# %%
population = pd.read_csv("population.csv", delimiter=",", index_col=0)
population.head(10)
# Out:
#    Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 0       1      1A                   14.241873  83.631834     A01
# 1       3      3A                    5.773992  74.960812     A04
# 2       3      3B                    7.459018  82.321565     A03
# 3       1      1C                   17.536114  77.406691     A03
# 4       3      3A                    6.836955  76.417829     A11
# 5       1      1C                   14.398468  84.699980     A08
# 6       1      1B                   15.228324  79.352084     A12
# 7       3      3A                    5.245370  75.160775     A05
# 8       4      4A                    8.185441  59.802541     A06
# 9       2      2C                   10.940774  73.247603     A08

# %% [markdown]
# ### Zadanie 1: Próba losowa [16 pkt]
#
# Podczas wydarzenia na terenie kompleksu sportowego znajduje się grupa ankieterów zadających kibicom pytanie o to jak w skali od 0 do 100 oceniają zakończony mecz.
# Ponieważ przepytanie wszyskich kibiców jest zbyt czasochłonne wnioski wyciągane będą na podstawie próby losowej.
#
# Wybierz z tablicy część danych, która odpowiada przeprowadzeniu badania według następujących scenariuszy.
#
# Podczas wykonania zadania przydatne mogą się okazać następujące funkcje:
#  - `pandas.DataFrame.sample()`
#  - `pandas.DataFrame.sort_values()`
#  - `pandas.DataFrame.groupby()`
#  - `pandas.DataFrame.apply()`
#
# Uwaga! Podczas tworzenia tabel nie należy resetować indeksu.
#
# #### a) Scenariusz 1
# Ankieterzy przepytują pierwsze 200 osób przekraczające bramę główną. Żadna z osób nie odmawia odpowiedzi na pytanie. Po udzieleniu odpowiedzi osoba przechodzi przez bramę i nie ma możliwości, by zadać pytanie więcej niż raz tej samej osobie.
#
# Wynik zapisz do zmiennej `sample_1`.

# %%
# YOUR CODE HERE
sample_1= population.head(200)
sample_1
#raise NotImplementedError()
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 0         1      1A                   14.241873  83.631834     A01
# 1         3      3A                    5.773992  74.960812     A04
# 2         3      3B                    7.459018  82.321565     A03
# 3         1      1C                   17.536114  77.406691     A03
# 4         3      3A                    6.836955  76.417829     A11
# ..      ...     ...                         ...        ...     ...
# 195       3      3A                    5.626469  78.873461     A14
# 196       1      1A                   13.889895  73.753537     A15
# 197       4      4B                    7.427924  61.149437     A08
# 198       1      1C                   14.001730  87.192621     A16
# 199       2      2C                   12.261124  63.306093     A13
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_1) == pd.DataFrame
assert sample_1.shape == (200, 5)
assert list(sample_1.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_1.index.unique())[0] == 200

# %% [markdown]
# #### b) Scenariusz 2
# Ankieterzy krążą w tłumie ludzi przemieszczających się do bramy głównej i proszą losowe osoby o odpowiedź na pytanie aż do uzyskania 200 odpowiedzi. Wybrane osoby nie odmawiają odpowiedzi na pytanie nawet jeśli udzielały już wcześniej na nie odpowiedzi.
#
# Wynik zapisz do zmiennej `sample_2`.

# %%
# YOUR CODE HERE
sample_2 = population.sample(n=200, replace=True)
print(sample_2)
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 47        4      4A                    5.133878  55.368779     A05
# 593       1      1A                   15.356930  79.143826     A05
# 711       1      1A                   12.613484  74.190945     A08
# 601       4      4C                    6.544903  55.976684     A06
# 770       5      5A                   10.587968  83.525927     A13
# ..      ...     ...                         ...        ...     ...
# 570       2      2C                   12.857877  66.555673     A03
# 450       5      5A                   11.404217  79.597326     A15
# 421       2      2B                   13.246825  75.712894     A13
# 559       3      3B                    6.658587  77.812061     A13
# 498       1      1C                   12.846692  84.471525     A03
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_2) == pd.DataFrame
assert sample_2.shape == (200, 5)
assert list(sample_2.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_2.index.unique())[0] < 200

# %% [markdown]
# #### c) Scenariusz 3
# Ankieterzy krążą w tłumie ludzi przemieszczających się do bramy głównej i proszą losowe osoby o odpowiedź na pytanie aż do uzyskania 200 odpowiedzi. Wybrane osoby odmawiają odpowiedzi na pytanie tylko jeśli udzielały już wcześniej na nie odpowiedzi.
#
# Wynik zapisz do zmiennej `sample_3`.

# %%
# YOUR CODE HERE
sample_3 = population[~population.index.isin(sample_1.index)].sample(n=200, random_state=42)
sample_3
#raise NotImplementedError()
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 310       4      4A                    5.433875  57.519701     A05
# 619       5      5A                   12.504623  84.595798     A16
# 765       2      2C                   11.833806  68.602378     A09
# 277       5      5A                   11.471244  81.927223     A07
# 381       1      1B                   14.864843  83.848365     A01
# ..      ...     ...                         ...        ...     ...
# 478       1      1C                   14.506413  81.327529     A16
# 672       2      2A                   13.137396  67.849094     A15
# 550       3      3B                    5.464908  77.775479     A05
# 709       1      1A                   15.933041  58.381356     A10
# 349       1      1C                   13.696548  75.182112     A11
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_3) == pd.DataFrame
assert sample_3.shape == (200, 5)
assert list(sample_3.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_3.index.unique())[0] == 200

# %% [markdown]
# #### d) Scenariusz 4
# Ankieterzy stoją przy bramkach wyjściowych z sektorów i proszą losowo wybrane osoby o odpowiedź na pytanie, aż do momentu uzyskania 200 odpowiedzi (po 40 z każdego sektora). Po udzieleniu odpowiedzi osoba przechodzi przez bramkę i nie ma możliwości, by zadać pytanie więcej niż raz tej samej osobie.
#
# Wynik zapisz do zmiennej `sample_4`.

# %%
# YOUR CODE HERE
samples_per_sector = []
for sector in population['Sektor'].unique():
    sector_data = population[population['Sektor'] == sector]
    sample_sector = sector_data.sample(n=40, random_state=42)
    samples_per_sector.append(sample_sector)

sample_4 = pd.concat(samples_per_sector)
sample_4
#raise NotImplementedError()
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 79        1      1A                   13.399515  88.406907     A02
# 19        1      1C                   15.386422  71.468416     A04
# 315       1      1C                   17.748744  75.283896     A07
# 370       1      1A                   14.501878  73.969637     A09
# 356       1      1C                   19.072307  84.938404     A05
# ..      ...     ...                         ...        ...     ...
# 222       5      5A                   11.317579  83.834358     A07
# 696       5      5A                   10.892835  89.000693     A04
# 297       5      5A                    9.835587  77.743587     A16
# 473       5      5A                   10.974567  90.122806     A06
# 152       5      5A                   10.017448  88.229366     A09
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_4) == pd.DataFrame
assert sample_4.shape == (200, 5)
assert list(sample_4.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_4.index.unique())[0] == 200
assert np.all(np.isclose(sample_4['Sektor'].value_counts().values, 40))

# %% [markdown]
# #### e) Scenariusz 5
# Ankieterzy stoją przy bramkach wyjściowych z sektorów i proszą losowo wybrane osoby o odpowiedź na pytanie, aż do momentu uzyskania 200 odpowiedzi (z każdego sektora proporcjonalnie do liczby zasiadających w nim osób). Po udzieleniu odpowiedzi osoba przechodzi przez bramkę i nie ma możliwości, by zadać pytanie więcej niż raz tej samej osobie.
#
# Wynik zapisz do zmiennej `sample_5`.

# %%
# YOUR CODE HERE
sample_5 = population.groupby("Sektor").sample(frac=0.25)
sample_5.sort_index()
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 2         3      3B                    7.459018  82.321565     A03
# 4         3      3A                    6.836955  76.417829     A11
# 5         1      1C                   14.398468  84.699980     A08
# 6         1      1B                   15.228324  79.352084     A12
# 7         3      3A                    5.245370  75.160775     A05
# ..      ...     ...                         ...        ...     ...
# 793       4      4B                    8.176548  58.381396     A12
# 794       4      4C                    6.948214  56.519219     A02
# 795       3      3A                    7.893312  70.416553     A15
# 797       1      1B                   12.673971  74.571819     A07
# 799       1      1A                   17.074336  85.012766     A15
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_5) == pd.DataFrame
assert sample_5.shape == (200, 5)
assert list(sample_5.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_5.index.unique())[0] == 200
assert np.all(np.isclose(sample_5['Sektor'].value_counts().values, [60, 50, 40, 30, 20]))

# %% [markdown]
# #### f) Scenariusz 6
# Ankieterzy wybierają losowo 4 autobusy i proszą wszystkie z osób w nich zasiadających o odpowiedź na pytanie. Żadna z osób nie odmawia odpowiedzi na pytanie. Odpowiedzi są zbierane po kolei więc nie ma możliwości, żeby ta sama osoba została zapytana więcej niż jeden raz.
#
# Wynik zapisz do zmiennej `sample_6`.

# %%
# YOUR CODE HERE
autobus = pd.Series(population["Autobus"].unique()).sample(n=4).values
sample_6 = population[population["Autobus"].isin(autobus) == True]
sample_6
# Out:
#      Sektor Wyjście  Czas przejścia przez bramę      Ocena Autobus
# 10        1      1B                   14.874357  69.390177     A15
# 12        4      4A                    7.860531  58.899546     A07
# 15        4      4B                    5.209152  57.651869     A07
# 22        5      5A                   10.912408  78.089810     A07
# 25        5      5A                   10.112206  82.496612     A14
# ..      ...     ...                         ...        ...     ...
# 789       1      1A                   17.076117  81.006037     A15
# 795       3      3A                    7.893312  70.416553     A15
# 797       1      1B                   12.673971  74.571819     A07
# 798       3      3A                    6.981127  75.173029     A07
# 799       1      1A                   17.074336  85.012766     A15
#
# [200 rows x 5 columns]

# %%
# Komórka testowa
assert type(sample_6) == pd.DataFrame
assert sample_6.shape == (200, 5)
assert list(sample_6.columns) == ['Sektor', 'Wyjście', 'Czas przejścia przez bramę', 'Ocena', 'Autobus']
assert np.shape(sample_6.index.unique())[0] == 200
assert np.shape(sample_6['Autobus'].unique())[0] == 4

# %% [markdown]
# #### g) Analiza metod
# Jakie są mocne i słabe strony poszczególnych podeść do zebrania próby losowej? Czy próby uzyskane za pomocą poszczególnych metod są w tym przypadku reprezentatywne?

# %% [markdown]
# YOUR ANSWER HERE
#
#
# #### Podejście pierwszych 200 osób przekraczających bramę główną(1):
#
# #### Mocne strony:
#
# -Proste w realizacji.
#
# -Zapewnia reprezentatywność wśród osób, które przechodzą przez bramę główną.
#
# #### Słabe strony:
#
# -Nie gwarantuje reprezentatywności dla całej populacji, szczególnie jeśli istnieje różnorodność w sposobach przemieszczania się.
#
#
# -Podejście losowego wyboru próbki ze wszystkich osób nawet jak udzielały odpowiedzi(2):
#
# Mocne strony:
#
# Proste w realizacji
#
# Ma większe prawdopodobieństwo reprezentatywności dla całej populacji.
#
# Słabe strony:
#
# Umożliwia pominięcie niektórych grup, co może zaburzyć reprezentatywność, jeśli dana grupa odpowiadała kilka razy na pytanie a inne wcale.
#
#
# Podejście losowego wyboru próbki z wyłączeniem osób, które już udzieliły odpowiedzi(3):
#
# Mocne strony:
#
# Zapewnia reprezentatywność, gdyż osoby które już udzielały odpowiedzi nie odpowiadają drugi raz na to samo pytanie.
#
# Może zapewnić bardziej zróżnicowaną próbkę.
#
# Słabe strony:
#
# Istnieje ryzyko, że niektóre osoby, które już udzieliły odpowiedzi, zostaną wykluczone z dalszego losowania próbki, co może wprowadzić pewne zniekształcenia w reprezentatywności próby, zwłaszcza jeśli osoby te są istotną częścią populacji lub reprezentują unikalne cechy.
#
#
# Podejście losowego wyboru próbki z każdego sektora (po 40 osób)(4):
#
# Mocne strony:
#
# Zróżnicowane odpowiedzi z każdego sektora
#
# Zapewnia reprezentatywność każdej z grup osób
#
# Słabe strony:
#
# Niektóre sektory zawierały więcej, niektóre mniej osób, więc wyniki nie są przeskalowane, co może zaburzać reprezentatywność .
#
#
# Podejście losowego wyboru próbki z każdego sektora (proporcjonalnie do ilości osób)(5):
#
# Mocne strony:
#
# Zróżnicowane odpowiedzi z każdego sektora
#
# Zapewnia reprezentatywność każdej z grup osób
#
# Słabe strony:
#
# Może być czasochłonne w realizacji
#
# W przypadku błędów w doborze sektorów lub nieprawidłowego losowania próbki z każdego sektora, istnieje ryzyko, że próbka nie będzie reprezentatywna dla całej populacji.
#
#
# Podejście wyboru losowego 4 autobusów i przepytanie wszystkich osób w nich(6):
#
# Mocne strony:
#
# Dobre zebranie informacji z danej grupy osób
#
# Proste i skuteczne w zbieraniu danych z różnych grup społecznych.
#
# Eliminuje koniecznośc selekcji w przeprowadzaniu próbki losowej
#
# Słabe strony:
#
# Może mocno zaburzać reprezentatywność ze względu na pominięcie reszty autobusów.
#
# Brak możliwości sprawdzenia rożnorodności wyników.
#
#
#
# Biorąc pod uwagę wszystkie scenariusze, najbardziej reprezentatywne mogą się okazać:
#
# Podejście losowego wyboru próbki z każdego sektora (proporocjonalnie do ilości osób)(Scenariusz 5)
#
# Podejście losowego wyboru próbki z każdego sektora (po 40 osób)(Scenariusz 4)
#
# Podejście losowego wyboru próbki z wyłączeniem osób, które już udzieliły odpowiedzi(Scenariusz 3)
#
# Te podejścia najbardziej eliminują ryzyko dużego pominięcia danej grupy, co zaburzałoby reprezentatywność.

# %% [markdown]
# ### Zadanie 2: Reprezentatywność próby losowej - część 1 [6 pkt]
#
# Z populacji o rozkładzie N(172, 7) wylosowano ze zwracaniem 4 próby losowe o identycznej liczebności i następujących parametrach:
#
# ![image.png](attachment:4e8324e1-de00-4605-b921-a5e9a497164c.png)
#
# Oceń reprezentatywność powyższych prób. Jaki może być ich wpływ na wyniki przeprowadzonych na ich podstawie analizy?

# %% [markdown]
# YOUR ANSWER HERE
#
#
# Dla analizy na podstawie próby losowej ważne jest to, czy jej rozkład będzie zbliżony do rozkłądu populacji (w tym przypadku teoretycznego rozkładu normalnego). Jeżeli przyjęte zostanie, iż rozkład próby jest taki jak rozkład populacji, a w rzeczywistości będzie się od niego znacznie różnił, to wszelkie analizy dostarczą nam błędnych wniosków.
#
# Normalność rozkładu można oszacować oceniając jego kształt, w tym: skośność oraz kurtozę. W tym przypadku, widać, że rozkład trzeciej próby losowej jest najbardziej podobny do rozkładu normalnego. Skośnośc i kurtoza są najbliższe zeru, a i jego statystyki są bardzo zbliżone do parametrów rozkładu teoretycznego. Próbę losową 2 również charakteryzują skośnośc i kurtoza bardzo bliskie zeru, choć widać, że brakuje w niej wartości na obydwu krańcach rozkładu. Rozkład próby losowej 1 jest lewoskośny względem rozkładu teoretycznego i ma wiele wartości skupionych wokół średniej. Czwartemu z rozkładów brakuje symetrii (bardziej niż dzwon przypomina wielbłąda?).
#
# Pomimo wszystkich różnic rozkłady każdej z prób są zbliżone do teoretycznego rzokładu normalnego N(172, 7). W związku z tym, można przypuszczać, że wnioskowanie oparte na tych próbach nie byłoby błędne.

# %% [markdown]
# ### Zadanie 3:  Reprezentatywność próby losowej - część 2 [6 pkt]
#
# Z populacji o rozkładzie N(172, 7) wylosowano ze zwracaniem 5000 prób losowych o liczebności 100. Na podstawie każdej z prób wyliczono jej wartość średnią, wariancję i odchylenie standardowe. Poniżej przedstawiono rozkłady wyliczonych parametrów:
#
# ![image.png](attachment:4671b7fb-e14e-4702-b98b-0e83199de43b.png)
#
# Oceń w jaki sposób reprezentatywność próby losowej może wpływać na wyniki przeprowadzonych na jej podstawie analizy?

# %% [markdown]
# YOUR ANSWER HERE
#
# Rozkład danej statystyki zależy od: schematu losowania próby, liczebności próby, rozkładu populacji, z której pochodzi oraz postaci funkcyjnej, z której pochodzi dana statystyka. Na przykład jeśli, tak jak w powyższym przykładzie, próba jest pobierana metodą losowania ze zwracaniem, to każdy element populacji ma równą szansę być wybranym. W rezultacie, rozkład statystyki w próbie będzie miał tendencję do bycia bardziej reprezentatywnym odzwierciedleniem rozkładu populacji. Ponadto, gdy próba losowa jest dostatecznie liczna, to można uznać, że rozkład empiryczny będzie się niewiele różnił od rozkładu teoretycznego. Próba jest tym bardziej reprezentatywna, im jest liczniejsza, a wnioskowanie jest bardziej precyzyjne.
